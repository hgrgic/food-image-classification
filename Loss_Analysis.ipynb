# %% [markdown]
# # Description
# This notebook represents a small utility tool used to analyse loss and accuracy from the stored history models.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from PIL import Image
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader
from torch import nn
from torch import optim
import torch

import time
from torchsummary import summary
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Data Copying
# Since we were running everything on Google Collab, this part would ensure that the data got copied from the mounted Google Drive to the Collab file system.

# %%
groot = '/content/drive/My Drive/AML'

# %%
history = torch.load(groot+"/hrvoje/history/fc_fitted_cnn_fitted_adam(0.0001)_schd(0.1_7steps).pt")

# %% [markdown]
# # Analysis

# %%
history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
# plt.savefig(groot+"/full/"+dataset+'_loss_curve.png')
plt.show()

# %%
plt.plot(history[:,2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0,1)
# plt.savefig(groot+"/full/"+dataset+'_accuracy_curve.png')
plt.show()
